# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
# Import the numpy and pandas packages

import numpy as np
import pandas as pd

# %% [markdown]
# ## Task 1: Reading and Inspection
#
# -  ### Subtask 1.1: Import and read
#
# Import and read the movie database. Store it in a variable called `movies`.

# %%
movies = pd.read_csv('Movie+Assignment+Data.csv')
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 5038  Color        Scott Smith                     1.0      87.0
# 5039  Color                NaN                    43.0      43.0
# 5040  Color   Benjamin Roberds                    13.0      76.0
# 5041  Color        Daniel Hsia                    14.0     100.0
# 5042  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %% [markdown]
# -  ### Subtask 1.2: Inspect the dataframe
#
# Inspect the dataframe's columns, shapes, variable types etc.

# %%
#column inspection
movies.columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
#number of rows
OriginalLen = len(movies.index)

# %%
#shape inspection
movies.shape
# Out:
# (5043, 28)

# %%
#data type, null-value column inspection
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#getting statistical information of numeric value columns
movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# ## Task 2: Cleaning the Data
#
# -  ### Subtask 2.1: Inspect Null values
#
# Find out the number of Null values in all the columns and rows. Also, find the percentage of Null values in each column. Round off the percentages upto two decimal places.

# %%
#code for column-wise null count here
movies.isnull().sum()
# Out:
# color                         19
# director_name                104
# num_critic_for_reviews        50
# duration                      15
# director_facebook_likes      104
# actor_3_facebook_likes        23
# actor_2_name                  13
# actor_1_facebook_likes         7
# gross                        884
# genres                         0
# actor_1_name                   7
# movie_title                    0
# num_voted_users                0
# cast_total_facebook_likes      0
# actor_3_name                  23
# facenumber_in_poster          13
# plot_keywords                153
# movie_imdb_link                0
# num_user_for_reviews          21
# language                      12
# country                        5
# content_rating               303
# budget                       492
# title_year                   108
# actor_2_facebook_likes        13
# imdb_score                     0
# aspect_ratio                 329
# movie_facebook_likes           0
# dtype: int64

# %%
# Write your code for row-wise null count here

for i in range(len(movies.index)) :
    print("row ", i , " : " ,  movies.iloc[i].isnull().sum())
# Out:
# row  0  :  0
# row  1  :  0
# row  2  :  0
# row  3  :  0
# row  4  :  14
# row  5  :  0
# row  6  :  0
# row  7  :  0
# row  8  :  0
# row  9  :  0
# row  10  :  0
# row  11  :  0
# row  12  :  0
# row  13  :  0
# row  14  :  0
# row  15  :  0
# row  16  :  0
# row  17  :  0
# row  18  :  0
# row  19  :  0
# row  20  :  0
# row  21  :  0
# row  22  :  0
# row  23  :  0
# row  24  :  0
# row  25  :  0
# row  26  :  0
# row  27  :  0
# row  28  :  0
# row  29  :  0
# row  30  :  0
# row  31  :  0
# row  32  :  0
# row  33  :  0
# row  34  :  0
# row  35  :  0
# row  36  :  0
# row  37  :  0
# row  38  :  0
# row  39  :  0
# row  40  :  0
# row  41  :  0
# row  42  :  0
# row  43  :  0
# row  44  :  0
# row  45  :  0
# row  46  :  0
# row  47  :  0
# row  48  :  0
# row  49  :  0
# row  50  :  0
# row  51  :  0
# row  52  :  0
# row  53  :  0
# row  54  :  0
# row  55  :  1
# row  56  :  0
# row  57  :  0
# row  58  :  0
# row  59  :  0
# row  60  :  0
# row  61  :  0
# row  62  :  0
# ...

# %%
#code for column-wise null percentages here

round((movies.isnull().sum() / len(movies.index)*100),2)
# Out:
# color                         0.38
# director_name                 2.06
# num_critic_for_reviews        0.99
# duration                      0.30
# director_facebook_likes       2.06
# actor_3_facebook_likes        0.46
# actor_2_name                  0.26
# actor_1_facebook_likes        0.14
# gross                        17.53
# genres                        0.00
# actor_1_name                  0.14
# movie_title                   0.00
# num_voted_users               0.00
# cast_total_facebook_likes     0.00
# actor_3_name                  0.46
# facenumber_in_poster          0.26
# plot_keywords                 3.03
# movie_imdb_link               0.00
# num_user_for_reviews          0.42
# language                      0.24
# country                       0.10
# content_rating                6.01
# budget                        9.76
# title_year                    2.14
# actor_2_facebook_likes        0.26
# imdb_score                    0.00
# aspect_ratio                  6.52
# ...

# %% [markdown]
# -  ### Subtask 2.2: Drop unecessary columns
#
# For this assignment, you will mostly be analyzing the movies with respect to the ratings, gross collection, popularity of movies, etc. So many of the columns in this dataframe are not required. So it is advised to drop the following columns.
# -  color
# -  director_facebook_likes
# -  actor_1_facebook_likes
# -  actor_2_facebook_likes
# -  actor_3_facebook_likes
# -  actor_2_name
# -  cast_total_facebook_likes
# -  actor_3_name
# -  duration
# -  facenumber_in_poster
# -  content_rating
# -  country
# -  movie_imdb_link
# -  aspect_ratio
# -  plot_keywords

# %%
# Write your code for dropping the columns here. It is advised to keep inspecting the dataframe after each set of operations 
movies.drop(['color',
'director_facebook_likes',
'actor_1_facebook_likes',
'actor_2_facebook_likes',
'actor_3_facebook_likes',
'actor_2_name',
'cast_total_facebook_likes',
'actor_3_name',
'duration',
'facenumber_in_poster',
'content_rating',
'country',
'movie_imdb_link',
'aspect_ratio',
'plot_keywords'], axis=1,inplace=True)

# %%
#inspection after deleting the columns
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   director_name           4939 non-null   object
#  1   num_critic_for_reviews  4993 non-null   float64
#  2   gross                   4159 non-null   float64
#  3   genres                  5043 non-null   object
#  4   actor_1_name            5036 non-null   object
#  5   movie_title             5043 non-null   object
#  6   num_voted_users         5043 non-null   int64
#  7   num_user_for_reviews    5022 non-null   float64
#  8   language                5031 non-null   object
#  9   budget                  4551 non-null   float64
#  10  title_year              4935 non-null   float64
#  11  imdb_score              5043 non-null   float64
#  12  movie_facebook_likes    5043 non-null   int64
# dtypes: float64(6), int64(2), object(5)
# memory usage: 512.3+ KB

# %%
movies.describe()
# Out:
#        num_critic_for_reviews         gross  num_voted_users  \
# count             4993.000000  4.159000e+03     5.043000e+03
# mean               140.194272  4.846841e+07     8.366816e+04
# std                121.601675  6.845299e+07     1.384853e+05
# min                  1.000000  1.620000e+02     5.000000e+00
# 25%                 50.000000  5.340988e+06     8.593500e+03
# 50%                110.000000  2.551750e+07     3.435900e+04
# 75%                195.000000  6.230944e+07     9.630900e+04
# max                813.000000  7.605058e+08     1.689764e+06
#
#        num_user_for_reviews        budget   title_year   imdb_score  \
# count           5022.000000  4.551000e+03  4935.000000  5043.000000
# mean             272.770808  3.975262e+07  2002.470517     6.442138
# std              377.982886  2.061149e+08    12.474599     1.125116
# min                1.000000  2.180000e+02  1916.000000     1.600000
# 25%               65.000000  6.000000e+06  1999.000000     5.800000
# ...

# %%
# inspection of null percentage again
round((movies.isnull().sum()/len(movies.index))*100,2)
# Out:
# director_name              2.06
# num_critic_for_reviews     0.99
# gross                     17.53
# genres                     0.00
# actor_1_name               0.14
# movie_title                0.00
# num_voted_users            0.00
# num_user_for_reviews       0.42
# language                   0.24
# budget                     9.76
# title_year                 2.14
# imdb_score                 0.00
# movie_facebook_likes       0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.3: Drop unecessary rows using columns with high Null percentages
#
# Now, on inspection you might notice that some columns have large percentage (greater than 5%) of Null values. Drop all the rows which have Null values for such columns.

# %%
#code for dropping the rows here
movies.dropna(subset=['gross'],inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5041        Daniel Hsia                    14.0      10443.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
round((movies.isnull().sum()/len(movies.index))*100,2)
# Out:
# director_name             0.07
# num_critic_for_reviews    0.07
# gross                     0.00
# genres                    0.00
# actor_1_name              0.10
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.02
# language                  0.07
# budget                    6.44
# title_year                0.07
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
#still we need to delete the budget columns -> null rows
movies.dropna(subset=['budget'],inplace=True)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
#inspecting null values column wise again
movies.isnull().sum()
# Out:
# director_name             0
# num_critic_for_reviews    1
# gross                     0
# genres                    0
# actor_1_name              3
# movie_title               0
# num_voted_users           0
# num_user_for_reviews      0
# language                  3
# budget                    0
# title_year                0
# imdb_score                0
# movie_facebook_likes      0
# dtype: int64

# %%
#checking the null value percentage after deleting the columnns with rows having null values > 5%
round((movies.isnull().sum()/len(movies.index))*100,2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.08
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.4: Drop unecessary rows
#
# Some of the rows might have greater than five NaN values. Such rows aren't of much use for the analysis and hence, should be removed.

# %%
# code for dropping the rows here
movies = movies[movies.isnull().sum(axis=1) <= 5]
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
#Finding of most ouccuring value in English column
movies['language'].mode()
# Out:
# 0    English
# dtype: object

# %% [markdown]
# -  ### Subtask 2.5: Fill NaN values
#
# You might notice that the `language` column has some NaN values. Here, on inspection, you will see that it is safe to replace all the missing values with `'English'`.

# %%
# code for filling the NaN values in the 'language' column here
vals = {'language':'English'}
movies = movies.fillna(value = vals)
movies
# Out:
#           director_name  num_critic_for_reviews        gross  \
# 0         James Cameron                   723.0  760505847.0
# 1        Gore Verbinski                   302.0  309404152.0
# 2            Sam Mendes                   602.0  200074175.0
# 3     Christopher Nolan                   813.0  448130642.0
# 5        Andrew Stanton                   462.0   73058679.0
# ...                 ...                     ...          ...
# 5033      Shane Carruth                   143.0     424760.0
# 5034   Neill Dela Llana                    35.0      70071.0
# 5035   Robert Rodriguez                    56.0    2040920.0
# 5037       Edward Burns                    14.0       4584.0
# 5042           Jon Gunn                    43.0      85222.0
#
#                                    genres     actor_1_name  \
# 0         Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1                Action|Adventure|Fantasy      Johnny Depp
# ...

# %%
#inspection of percentage null values after filling NaN values of language column
round((movies.isnull().sum()/len(movies.index))*100,2)
# Out:
# director_name             0.00
# num_critic_for_reviews    0.03
# gross                     0.00
# genres                    0.00
# actor_1_name              0.08
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %% [markdown]
# -  ### Subtask 2.6: Check the number of retained rows
#
# You might notice that two of the columns viz. `num_critic_for_reviews` and `actor_1_name` have small percentages of NaN values left. You can let these columns as it is for now. Check the number and percentage of the rows retained after completing all the tasks above.

# %%
# code for checking number of retained rows here
# number of retained rows
len(movies.index)
# Out:
# 3891

# %%
#percentage of retained rows
(len(movies.index)/OriginalLen)*100
# Out:
# 77.15645449137418

# %% [markdown]
# **Checkpoint 1:** You might have noticed that we still have around `77%` of the rows!

# %% [markdown]
# ## Task 3: Data Analysis
#
# -  ### Subtask 3.1: Change the unit of columns
#
# Convert the unit of the `budget` and `gross` columns from `$` to `million $`.

# %%
#code for unit conversion here
movies['gross'] = movies['gross']/1000000
movies['budget'] = movies['budget']/1000000
movies[['gross','budget']]
# Out:
#            gross    budget
# 0     760.505847  237.0000
# 1     309.404152  300.0000
# 2     200.074175  245.0000
# 3     448.130642  250.0000
# 5      73.058679  263.7000
# ...          ...       ...
# 5033    0.424760    0.0070
# 5034    0.070071    0.0070
# 5035    2.040920    0.0070
# 5037    0.004584    0.0090
# 5042    0.085222    0.0011
#
# [3891 rows x 2 columns]

# %% [markdown]
# -  ### Subtask 3.2: Find the movies with highest profit
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`

# %%
# adding Profit column to the dataframe having difference of the gross and budget columns
movies['Profit'] = movies['gross'] - movies['budget']
movies['Profit']
# Out:
# 0       523.505847
# 1         9.404152
# 2       -44.925825
# 3       198.130642
# 5      -190.641321
#            ...
# 5033      0.417760
# 5034      0.063071
# 5035      2.033920
# 5037     -0.004416
# 5042      0.084122
# Name: Profit, Length: 3891, dtype: float64

# %%
# code for sorting the dataframe here
movies.sort_values('Profit', ascending=False, inplace=True)
movies
# Out:
#          director_name  num_critic_for_reviews       gross  \
# 0        James Cameron                   723.0  760.505847
# 29     Colin Trevorrow                   644.0  652.177271
# 26       James Cameron                   315.0  658.672302
# 3024      George Lucas                   282.0  460.935665
# 3080  Steven Spielberg                   215.0  434.949459
# ...                ...                     ...         ...
# 2334   Katsuhiro Ôtomo                   105.0    0.410388
# 2323    Hayao Miyazaki                   174.0    2.298191
# 3005      Lajos Koltai                    73.0    0.195888
# 3859    Chan-wook Park                   202.0    0.211667
# 2988      Joon-ho Bong                   363.0    2.201412
#
#                                                  genres         actor_1_name  \
# 0                       Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29                     Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# ...

# %%
#top 10 profiting movies here

top10 = movies.head(10)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
# checking for duplcate rows
movies[movies.duplicated()]
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 17             Joss Whedon                   703.0  623.279547
# 174            Bill Condon                   322.0  292.298923
# 395              Rob Cohen                   187.0  144.512310
# 2025          Herbert Ross                    60.0   80.000000
# 656         Paul Verhoeven                   196.0  119.412921
# 663    Angelina Jolie Pitt                   322.0  115.603980
# 3193           Paul Haggis                   287.0   54.557348
# 2619        John Carpenter                   318.0   47.000000
# 3984        Peter Cattaneo                   122.0   45.857453
# 2181             Jon Lucas                    81.0   55.461307
# 1984          Ole Bornedal                   264.0   49.122319
# 2628            Shawn Levy                    69.0   47.811275
# 2935           Tamra Davis                   111.0   37.188667
# 3017           Guy Ritchie                   151.0   30.093107
# ...

# %% [markdown]
# ### Subtask 3.3: Drop duplicate values
#
# After you found out the top 10 profiting movies, you might have notice a duplicate value. So, it seems like the dataframe has duplicate values as well. Drop the duplicate values from the dataframe and repeat `Subtask 3.2`.

# %%
# Write your code for dropping duplicate values here
movies.drop_duplicates(keep=False,inplace=True)

# %%
#checking again for the duplicate values -> this time it must not display any duplicate values
movies[movies.duplicated()]
# Out:
# Empty DataFrame
# Columns: [director_name, num_critic_for_reviews, gross, genres, actor_1_name, movie_title, num_voted_users, num_user_for_reviews, language, budget, title_year, imdb_score, movie_facebook_likes, Profit]
# Index: []

# %%
# code for repeating subtask 2 here

#creating Profit column
movies['Profit'] = movies['gross'] - movies['budget']

# sorting based on the Profit column
movies.sort_values('Profit', ascending=False, inplace=True)

#top 10 profiting movies here

top10 = movies.head(10)
top10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
# 439           Gary Ross                   673.0  407.999255
# 812          Tim Miller                   579.0  363.024263
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %% [markdown]
# **Checkpoint 2:** You might spot two movies directed by `James Cameron` in the list.

# %% [markdown]
# -  ### Subtask 3.4: Find IMDb Top 250
#
#     1. Create a new dataframe `IMDb_Top_250` and store the top 250 movies with the highest IMDb Rating (corresponding to the column: `imdb_score`). Also make sure that for all of these movies, the `num_voted_users` is greater than 25,000.
# Also add a `Rank` column containing the values 1 to 250 indicating the ranks of the corresponding films.
#     2. Extract all the movies in the `IMDb_Top_250` dataframe which are not in the English language and store them in a new dataframe named `Top_Foreign_Lang_Film`.

# %%
# Write your code for extracting the top 250 movies as per the IMDb score here. Make sure that you store it in a new dataframe 
# and name that dataframe as 'IMDb_Top_250'

#sort according to imdb_score
IMDb_Top_250 = movies.sort_values('imdb_score', ascending=False)

#filter according to num_voted_users>25000
IMDb_Top_250 = IMDb_Top_250.loc[(IMDb_Top_250.num_voted_users > 25000)]

#extract top 250 columns
IMDb_Top_250 = IMDb_Top_250.head(250)

#add Rank column
IMDb_Top_250['Rank'] = [x for x in range(1,251)]

IMDb_Top_250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# 2837  Francis Ford Coppola                   149.0   57.300000
# 66       Christopher Nolan                   645.0  533.316061
# 4498          Sergio Leone                   181.0    6.100000
# ...                    ...                     ...         ...
# 1735         James Mangold                   291.0  119.518352
# 927         Andrew Adamson                   212.0  267.652016
# 1606       Nick Cassavetes                   177.0    0.064286
# 525         Alfonso Cuarón                   372.0   35.286428
# 353          John Lasseter                   191.0  245.823397
#
#                                          genres           actor_1_name  \
# 1937                                Crime|Drama         Morgan Freeman
# ...

# %%
#extract top foreign language films from 'IMDb_Top_250' here
Top_Foreign_Lang_Film = IMDb_Top_250.loc[(IMDb_Top_250.language != 'English')]
Top_Foreign_Lang_Film
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4747                    Akira Kurosawa                   153.0    0.269061
# 4029                Fernando Meirelles                   214.0    7.563397
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4921                      Majid Majidi                    46.0    0.925402
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 1329                    S.S. Rajamouli                    44.0    6.498000
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 1298                Jean-Pierre Jeunet                   242.0   33.201661
# 4659                    Asghar Farhadi                   354.0    7.098492
# 4105                    Chan-wook Park                   305.0    2.181290
# ...

# %% [markdown]
# **Checkpoint 3:** Can you spot `Veer-Zaara` in the dataframe?

# %% [markdown]
# - ### Subtask 3.5: Find the best directors
#
#     1. Group the dataframe using the `director_name` column.
#     2. Find out the top 10 directors for whom the mean of `imdb_score` is the highest and store them in a new dataframe `top10director`.

# %%
# code for extracting the top 10 directors here
movies_gb_object = movies.groupby('director_name')
topdirectors = pd.DataFrame(movies_gb_object['imdb_score'].mean())
topdirectors.sort_values('imdb_score', ascending=False, inplace=True)
top10director = topdirectors.head(10)
top10director
# Out:
#                        imdb_score
# director_name
# Charles Chaplin          8.600000
# Tony Kaye                8.600000
# Majid Majidi             8.500000
# Ron Fricke               8.500000
# Damien Chazelle          8.500000
# Alfred Hitchcock         8.500000
# Sergio Leone             8.433333
# Christopher Nolan        8.425000
# S.S. Rajamouli           8.400000
# Marius A. Markevicius    8.400000

# %% [markdown]
# **Checkpoint 4:** No surprises that `Damien Chazelle` (director of Whiplash and La La Land) is in this list.

# %% [markdown]
# -  ### Subtask 3.6: Find popular genres
#
# You might have noticed the `genres` column in the dataframe with all the genres of the movies seperated by a pipe (`|`). Out of all the movie genres, the first two are most significant for any film.
#
# 1. Extract the first two genres from the `genres` column and store them in two new columns: `genre_1` and `genre_2`. Some of the movies might have only one genre. In such cases, extract the single genre into both the columns, i.e. for such movies the `genre_2` will be the same as `genre_1`.
# 2. Group the dataframe using `genre_1` as the primary column and `genre_2` as the secondary column.
# 3. Find out the 5 most popular combo of genres by finding the mean of the gross values using the `gross` column and store them in a new dataframe named `PopGenre`.

# %%
# code for extracting the first two genres of each movie here

g = movies['genres'].apply(lambda y: pd.Series(y.split('|')))

#Group the dataframe using genre_1 as the primary column and genre_2 as the secondary column.
movies['genre_1'] = g[0]
movies['genre_2'] = g[1]

#Some of the movies might have only one genre. In such cases, extract the single genre into both the columns
movies.loc[pd.isnull(movies['genre_2']), ['genre_2']] = movies['genre_1']

# %%
movies['genre_1']
# Out:
# 0          Action
# 29         Action
# 26          Drama
# 3024       Action
# 3080       Family
#           ...
# 2334       Action
# 2323    Adventure
# 3005        Drama
# 3859        Crime
# 2988       Comedy
# Name: genre_1, Length: 3821, dtype: object

# %%
movies['genre_2']
# Out:
# 0       Adventure
# 29      Adventure
# 26        Romance
# 3024    Adventure
# 3080       Sci-Fi
#           ...
# 2334    Adventure
# 2323    Animation
# 3005      Romance
# 3859        Drama
# 2988        Drama
# Name: genre_2, Length: 3821, dtype: object

# %%
#group data using genre_1 as primary column genre_2 as secondary column

movies_by_segment = movies.groupby(['genre_1','genre_2'])

print(movies_by_segment)

# %%
# code for getting the 5 most popular combo of genres here

PopGenre = movies_by_segment['gross'].mean()
PopGenre = PopGenre.sort_values(ascending = False)
PopGenre = PopGenre.head(5)
PopGenre
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       121.463622
#            Animation    116.998550
# Action     Adventure    108.789045
# Name: gross, dtype: float64

# %% [markdown]
# **Checkpoint 5:** Well, as it turns out. `Family + Sci-Fi` is the most popular combo of genres out there!

# %% [markdown]
# -  ### Subtask 3.7: Find the critic-favorite and audience-favorite actors
#
#     1. Create three new dataframes namely, `Meryl_Streep`, `Leo_Caprio`, and `Brad_Pitt` which contain the movies in which the actors: 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' are the lead actors. Use only the `actor_1_name` column for extraction. Also, make sure that you use the names 'Meryl Streep', 'Leonardo DiCaprio', and 'Brad Pitt' for the said extraction.
#     2. Append the rows of all these dataframes and store them in a new dataframe named `Combined`.
#     3. Group the combined dataframe using the `actor_1_name` column.
#     4. Find the mean of the `num_critic_for_reviews` and `num_user_for_review` and identify the actors which have the highest mean.

# %%
# code for creating three new dataframes here
# Include all movies in which Meryl_Streep is the lead

Meryl_Streep = movies.loc[(movies.actor_1_name == 'Meryl Streep')]
Meryl_Streep
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 1408   David Frankel                   208.0  124.732962
# 1575  Sydney Pollack                    66.0   87.100000
# 1204     Nora Ephron                   252.0   94.125426
# 1618   David Frankel                   234.0   63.536011
# 410     Nancy Meyers                   187.0  112.703470
# 2781  Phyllida Lloyd                   331.0   29.959436
# 1925  Stephen Daldry                   174.0   41.597830
# 3135   Robert Altman                   211.0   20.338609
# 1106   Curtis Hanson                    42.0   46.815748
# 1674   Carl Franklin                    64.0   23.209440
# 1483  Robert Redford                   227.0   14.998070
#
#                                genres  actor_1_name  \
# 1408             Comedy|Drama|Romance  Meryl Streep
# 1575          Biography|Drama|Romance  Meryl Streep
# 1204          Biography|Drama|Romance  Meryl Streep
# 1618             Comedy|Drama|Romance  Meryl Streep
# ...

# %%
# Include all movies in which Leo_Caprio is the lead
Leo_Caprio = movies.loc[(movies.actor_1_name == 'Leonardo DiCaprio')]
Leo_Caprio
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 26            James Cameron                   315.0  658.672302
# 97        Christopher Nolan                   642.0  292.568851
# 911        Steven Spielberg                   194.0  164.435221
# 296       Quentin Tarantino                   765.0  162.804648
# 179   Alejandro G. Iñárritu                   556.0  183.635922
# 452         Martin Scorsese                   490.0  127.968405
# 361         Martin Scorsese                   352.0  132.373442
# 50             Baz Luhrmann                   490.0  144.812796
# 3476           Baz Luhrmann                   490.0  144.812796
# 2757           Baz Luhrmann                   106.0   46.338728
# 1422        Randall Wallace                    83.0   56.876365
# 308         Martin Scorsese                   606.0  116.866727
# 1453         Clint Eastwood                   392.0   37.304950
# 257         Martin Scorsese                   267.0  102.608827
# ...

# %%
# Include all movies in which Brad_Pitt is the lead

Brad_Pitt =  movies.loc[(movies.actor_1_name == 'Brad Pitt')]
Brad_Pitt
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 400       Steven Soderbergh                   186.0  183.405771
# 255              Doug Liman                   233.0  186.336103
# 940             Neil Jordan                   120.0  105.264608
# 470              David Ayer                   406.0   85.707116
# 254       Steven Soderbergh                   198.0  125.531634
# 2204  Alejandro G. Iñárritu                   285.0   34.300771
# 2682         Andrew Dominik                   414.0   14.938570
# 2898             Tony Scott                   122.0   12.281500
# 2333    Angelina Jolie Pitt                   131.0    0.531009
# 1490        Terrence Malick                   584.0   13.303319
# 101           David Fincher                   362.0  127.490802
# 683           David Fincher                   315.0   37.023395
# 1722         Andrew Dominik                   273.0    3.904982
# 611     Jean-Jacques Annaud                    76.0   37.901509
# ...

# %%
# code for combining the three dataframes here
a1 = Meryl_Streep.append(Leo_Caprio)
Combined = a1.append(Brad_Pitt)
Combined
# Out:
#               director_name  num_critic_for_reviews       gross  \
# 1408          David Frankel                   208.0  124.732962
# 1575         Sydney Pollack                    66.0   87.100000
# 1204            Nora Ephron                   252.0   94.125426
# 1618          David Frankel                   234.0   63.536011
# 410            Nancy Meyers                   187.0  112.703470
# 2781         Phyllida Lloyd                   331.0   29.959436
# 1925         Stephen Daldry                   174.0   41.597830
# 3135          Robert Altman                   211.0   20.338609
# 1106          Curtis Hanson                    42.0   46.815748
# 1674          Carl Franklin                    64.0   23.209440
# 1483         Robert Redford                   227.0   14.998070
# 26            James Cameron                   315.0  658.672302
# 97        Christopher Nolan                   642.0  292.568851
# 911        Steven Spielberg                   194.0  164.435221
# ...

# %%
#code for grouping the combined dataframe here
#Group the combined dataframe using the actor_1_name column.

grp = Combined.groupby(['actor_1_name'])

# %%
#code for finding the mean of critic reviews and audience reviews here
#Find the mean of the num_critic_for_reviews and num_user_for_reviews and identify the 
#actors which have the highest mean


meanOfActors = grp[['num_critic_for_reviews','num_user_for_reviews']].mean()
meanOfActors = meanOfActors.sort_values(['num_critic_for_reviews','num_user_for_reviews'], ascending=[False,False])
meanOfActors
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Leonardo DiCaprio              330.190476            914.476190
# Brad Pitt                      245.000000            742.352941
# Meryl Streep                   181.454545            297.181818

# %% [markdown]
# **Checkpoint 6:** `Leonardo` has aced both the lists!
